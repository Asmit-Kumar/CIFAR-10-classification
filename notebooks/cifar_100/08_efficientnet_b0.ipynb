# %% [markdown]
# # CIFAR-100 - EfficientNet-B0-Like From Scratch
#
# This notebook trains a custom EfficientNet-B0-like classifier on CIFAR-100 using the shared project utilities. It serves as the main from-scratch EfficientNet baseline before scaling up to the B3-like experiment.
#
# ## Experiment Summary
#
# | Item | Setting |
# |------|---------|
# | Dataset | CIFAR-100 |
# | Input size | 224 x 224 |
# | Initialization | From scratch |
# | Model | Custom EfficientNet-B0-like network |
# | Parameters | 4,135,648 |
# | Training | SGD with Nesterov momentum and OneCycleLR stepped per batch |
# | Regularization | Label smoothing, MixUp, stochastic depth, SE blocks, dropout |
# | Checkpoints | `../checkpoint/efficient_net_v5_onecycle150_100_*` |
# | Stored output result | Best validation: 77.31%; test: 77.83% |
#
# ## Reproducibility Note
#
# The saved output cells are from a 150-epoch run, while the current training cell sets `EPOCHS = 120`. Rerunning the notebook from the current code will not exactly reproduce the stored training log unless the epoch count is intentionally restored.

# %% [markdown]
# ## Imports
#
# Load PyTorch, AMP, optimizer/scheduler components, and the shared project helpers for CIFAR-100 data loading, training, checkpointing, and plotting.

# %%
import sys

from ipykernel.kernelapp import kernel_flags
from torch.ao.pruning import scheduler

sys.path.append('../..')

import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from torch import optim
from torch.amp import GradScaler

from utils.dataset import get_cifar100_dataloaders, CIFAR100_CLASSES
from utils.training import fit, test_accuracy
from utils.callbacks import ModelCheckpoint
from utils.plotting import plot_training_curves, show_sample_batch

# %% [markdown]
# ## Device Setup
#
# Select CUDA when it is available and enable cuDNN benchmarking for faster convolution kernels on fixed-size image batches.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if device.type == 'cuda':
    torch.backends.cudnn.benchmark = True
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %% [markdown]
# ## Data
#
# Build CIFAR-100 train, validation, and test loaders with `batch_size=128`. Images are resized to `224 x 224` and normalized with ImageNet statistics so this scratch baseline is comparable with the project's high-resolution CIFAR-100 runs.
#
# The shared loader keeps an 80/20 split from the official 50,000-image training set and evaluates on the official 10,000-image test set.

# %%
batch_size = 128

trainloader, valloader, testloader = get_cifar100_dataloaders(
    batch_size=batch_size,
    num_workers=4,
    img_size=224,
    use_imagenet_stats=True,
    interpolation=transforms.InterpolationMode.LANCZOS,
)
print(f'Train: {len(trainloader)} | Val: {len(valloader)} | Test: {len(testloader)}')
# Out:
# C:\Users\asmit\PycharmProjects\CIFAR_10\.venv\Lib\site-packages\torchvision\datasets\cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# Train: 313 | Val: 79 | Test: 79

# %% [markdown]
# ## Model Architecture
#
# Define the EfficientNet-style model from small reusable blocks before instantiating it. The architecture uses squeeze-and-excitation attention, depthwise separable convolutions, MBConv blocks, stochastic depth, and dropout before the CIFAR-100 classifier.

# %%
class SEBlock(nn.Module):
    """
    Squeeze-and-Excitation block.
    se_ratio=0.25 is applied to the *block input* channels (pre-expansion),
    matching the official EfficientNet paper (Tan et al., 2019).
    """
    def __init__(self, expanded_channels, block_input_channels, se_ratio=0.25):
        super(SEBlock, self).__init__()
        squeezed = max(1, int(block_input_channels * se_ratio))
        self.se = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(expanded_channels, squeezed, bias=True),
            nn.SiLU(),
            nn.Linear(squeezed, expanded_channels, bias=True),
            nn.Sigmoid(),
        )

    def forward(self, x):
        return x * self.se(x).view(x.size(0), x.size(1), 1, 1)

# %% [markdown]
# ### Depthwise Separable Block
#
# Wrap depthwise convolution, batch normalization, SiLU activation, SE attention, and pointwise projection into one reusable block. The SE squeeze width is based on the block input channels, matching the EfficientNet paper.

# %%
class DepthwiseSeparableConv(nn.Module):
    """
    Depthwise conv -> BN -> SiLU -> SE -> Pointwise conv -> BN.
    SE ratio is applied to block_input_channels (pre-expansion), per paper.
    """
    def __init__(self, in_channels, out_channels, block_input_channels,
                 kernel_size=3, stride=1, se_ratio=0.25):
        super(DepthwiseSeparableConv, self).__init__()
        self.depthwise = nn.Sequential(
            nn.Conv2d(
                in_channels, in_channels,
                kernel_size, stride,
                padding=kernel_size // 2,
                groups=in_channels,
                bias=False
            ),
            nn.BatchNorm2d(in_channels),
            nn.SiLU()
        )

        self.se = SEBlock(in_channels, block_input_channels, se_ratio)

        self.pointwise = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False),
            nn.BatchNorm2d(out_channels)
        )

    def forward(self, x):
        x = self.depthwise(x)
        x = self.se(x)
        x = self.pointwise(x)
        return x

# %% [markdown]
# ### MBConv and Stochastic Depth
#
# Define drop-path regularization and the mobile inverted bottleneck block. Residual connections are used only when stride and channel count allow an identity shortcut.

# %%
class StochasticDepth(nn.Module):
    """Drop Path (Stochastic Depth) regularization per block."""
    def __init__(self, drop_prob: float = 0.0):
        super().__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if not self.training or self.drop_prob == 0.0:
            return x
        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)
        random_tensor = torch.rand(shape, dtype=x.dtype, device=x.device)
        random_tensor = torch.floor(random_tensor + keep_prob)
        return x * random_tensor / keep_prob


class MBConv(nn.Module):
    """
    Mobile Inverted Bottleneck Convolution block.
      t=1  -> MBConv1: no expansion (used in Stage 1 only)
      t=6  -> MBConv6: 6x expansion (used in Stages 2-7)
    Stochastic Depth is applied to the residual branch during training.
    """
    def __init__(self, in_channels, out_channels, stride=1,
                 kernel_size=3, t=6, drop_path_rate=0.0):
        super(MBConv, self).__init__()
        expanded = in_channels * t

        # Expansion phase (identity when t=1, i.e. MBConv1)
        if t > 1:
            self.expansion = nn.Sequential(
                nn.Conv2d(in_channels, expanded, kernel_size=1, bias=False),
                nn.BatchNorm2d(expanded),
                nn.SiLU()
            )
        else:
            self.expansion = nn.Identity()

        self.depthwise = DepthwiseSeparableConv(
            in_channels=expanded,
            out_channels=out_channels,
            block_input_channels=in_channels,  # SE squeezed on pre-expansion channels
            kernel_size=kernel_size,
            stride=stride,
        )

        self.use_residual = (stride == 1 and in_channels == out_channels)
        self.stochastic_depth = StochasticDepth(drop_path_rate)

    def forward(self, x):
        identity = x
        out = self.expansion(x)
        out = self.depthwise(out)
        if self.use_residual:
            out = self.stochastic_depth(out)
            out = out + identity
        return out

# %% [markdown]
# ### EfficientNet-B0-Like Network
#
# Assemble the B0-like stage schedule with 16 MBConv blocks, a 1280-channel head, global pooling, dropout, and a 100-class linear classifier.

# %%
class EfficientNet(nn.Module):
    """
    EfficientNet-B0-like architecture, corrected to match the paper:
      - Stage 1 uses MBConv1 (t=1, no expansion channel inflation)
      - SE ratio = 0.25 applied to block input channels (pre-expansion)
      - Stochastic Depth linearly scaled 0.0 -> drop_path_rate across all blocks
      - Head Dropout(p=0.2) before classifier
    """
    def __init__(self, num_classes=100, drop_path_rate=0.2, dropout_rate=0.2):
        super(EfficientNet, self).__init__()

        # Stage config: (num_blocks, in_ch, out_ch, kernel, stride, t)
        stage_cfg = [
            (1, 32,  16,  3, 1, 1),   # Stage 1: MBConv1 (t=1, no expansion)
            (2, 16,  24,  3, 2, 6),   # Stage 2: MBConv6
            (2, 24,  40,  5, 2, 6),   # Stage 3
            (3, 40,  80,  3, 2, 6),   # Stage 4
            (3, 80,  112, 5, 1, 6),   # Stage 5
            (4, 112, 192, 5, 2, 6),   # Stage 6
            (1, 192, 320, 3, 1, 6),   # Stage 7
        ]

        total_blocks = sum(cfg[0] for cfg in stage_cfg)
        block_idx = 0

        # Stem
        self.stem = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(32),
            nn.SiLU()
        )

        # Build all stages dynamically
        stages = []
        for (num_blocks, in_ch, out_ch, k, s, t) in stage_cfg:
            layers = []
            for i in range(num_blocks):
                dp_rate = drop_path_rate * block_idx / total_blocks
                layers.append(MBConv(
                    in_channels=in_ch if i == 0 else out_ch,
                    out_channels=out_ch,
                    stride=s if i == 0 else 1,
                    kernel_size=k,
                    t=t,
                    drop_path_rate=dp_rate,
                ))
                block_idx += 1
            stages.append(nn.Sequential(*layers))

        self.stages = nn.Sequential(*stages)

        # Head
        self.head = nn.Sequential(
            nn.Conv2d(320, 1280, kernel_size=1, bias=False),
            nn.BatchNorm2d(1280),
            nn.SiLU()
        )

        # Pooling + Dropout + Classifier
        self.global_pool = nn.AdaptiveAvgPool2d(1)
        self.dropout = nn.Dropout(p=dropout_rate)
        self.classifier = nn.Linear(1280, num_classes)

        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.ones_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)

    def forward(self, x):
        x = self.stem(x)
        x = self.stages(x)
        x = self.head(x)
        x = self.global_pool(x)
        x = torch.flatten(x, 1)
        x = self.dropout(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# ### Model Summary
#
# Instantiate the model on the selected device and print the architecture plus parameter count before configuring the actual training run.

# %%
model = EfficientNet().to(device)
print(model)
print(f'\nTotal parameters: {sum(p.numel() for p in model.parameters()):,}')
# Out:
# EfficientNet(
#   (stem): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): SiLU()
#   )
#   (stages): Sequential(
#     (0): Sequential(
#       (0): MBConv(
#         (expansion): Identity()
#         (depthwise): DepthwiseSeparableConv(
#           (depthwise): Sequential(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU()
#           )
#           (se): SEBlock(
#             (se): Sequential(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): Flatten(start_dim=1, end_dim=-1)
#               (2): Linear(in_features=32, out_features=8, bias=True)
#               (3): SiLU()
#               (4): Linear(in_features=8, out_features=32, bias=True)
#               (5): Sigmoid()
#             )
#           )
#           (pointwise): Sequential(
#             (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth()
#       )
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (expansion): Sequential(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depthwise): DepthwiseSeparableConv(
#           (depthwise): Sequential(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU()
#           )
#           (se): SEBlock(
#             (se): Sequential(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): Flatten(start_dim=1, end_dim=-1)
#               (2): Linear(in_features=96, out_features=4, bias=True)
#               (3): SiLU()
#               (4): Linear(in_features=4, out_features=96, bias=True)
#               (5): Sigmoid()
#             )
#           )
#           (pointwise): Sequential(
#             (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth()
#       )
#       (1): MBConv(
#         (expansion): Sequential(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depthwise): DepthwiseSeparableConv(
#           (depthwise): Sequential(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU()
#           )
#           (se): SEBlock(
#             (se): Sequential(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): Flatten(start_dim=1, end_dim=-1)
#               (2): Linear(in_features=144, out_features=6, bias=True)
#               (3): SiLU()
#               (4): Linear(in_features=6, out_features=144, bias=True)
#               (5): Sigmoid()
#             )
#           )
#           (pointwise): Sequential(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth()
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (expansion): Sequential(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depthwise): DepthwiseSeparableConv(
#           (depthwise): Sequential(
#             (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU()
#           )
#           (se): SEBlock(
#             (se): Sequential(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): Flatten(start_dim=1, end_dim=-1)
#               (2): Linear(in_features=144, out_features=6, bias=True)
#               (3): SiLU()
#               (4): Linear(in_features=6, out_features=144, bias=True)
#               (5): Sigmoid()
#             )
#           )
#           (pointwise): Sequential(
#             (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth()
#       )
#       (1): MBConv(
#         (expansion): Sequential(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depthwise): DepthwiseSeparableConv(
#           (depthwise): Sequential(
#             (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU()
#           )
#           (se): SEBlock(
#             (se): Sequential(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): Flatten(start_dim=1, end_dim=-1)
#               (2): Linear(in_features=240, out_features=10, bias=True)
#               (3): SiLU()
#               (4): Linear(in_features=10, out_features=240, bias=True)
#               (5): Sigmoid()
#             )
#           )
#           (pointwise): Sequential(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth()
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (expansion): Sequential(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depthwise): DepthwiseSeparableConv(
#           (depthwise): Sequential(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU()
#           )
#           (se): SEBlock(
#             (se): Sequential(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): Flatten(start_dim=1, end_dim=-1)
#               (2): Linear(in_features=240, out_features=10, bias=True)
#               (3): SiLU()
#               (4): Linear(in_features=10, out_features=240, bias=True)
#               (5): Sigmoid()
#             )
#           )
#           (pointwise): Sequential(
#             (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth()
#       )
#       (1): MBConv(
#         (expansion): Sequential(
#           (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depthwise): DepthwiseSeparableConv(
#           (depthwise): Sequential(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU()
#           )
#           (se): SEBlock(
#             (se): Sequential(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): Flatten(start_dim=1, end_dim=-1)
#               (2): Linear(in_features=480, out_features=20, bias=True)
#               (3): SiLU()
#               (4): Linear(in_features=20, out_features=480, bias=True)
#               (5): Sigmoid()
#             )
#           )
#           (pointwise): Sequential(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth()
#       )
#       (2): MBConv(
#         (expansion): Sequential(
#           (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depthwise): DepthwiseSeparableConv(
#           (depthwise): Sequential(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU()
#           )
#           (se): SEBlock(
#             (se): Sequential(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): Flatten(start_dim=1, end_dim=-1)
#               (2): Linear(in_features=480, out_features=20, bias=True)
#               (3): SiLU()
#               (4): Linear(in_features=20, out_features=480, bias=True)
#               (5): Sigmoid()
#             )
#           )
#           (pointwise): Sequential(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth()
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (expansion): Sequential(
#           (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depthwise): DepthwiseSeparableConv(
#           (depthwise): Sequential(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU()
#           )
#           (se): SEBlock(
#             (se): Sequential(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): Flatten(start_dim=1, end_dim=-1)
#               (2): Linear(in_features=480, out_features=20, bias=True)
#               (3): SiLU()
#               (4): Linear(in_features=20, out_features=480, bias=True)
#               (5): Sigmoid()
#             )
#           )
#           (pointwise): Sequential(
#             (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth()
#       )
#       (1): MBConv(
#         (expansion): Sequential(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depthwise): DepthwiseSeparableConv(
#           (depthwise): Sequential(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU()
#           )
#           (se): SEBlock(
#             (se): Sequential(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): Flatten(start_dim=1, end_dim=-1)
#               (2): Linear(in_features=672, out_features=28, bias=True)
#               (3): SiLU()
#               (4): Linear(in_features=28, out_features=672, bias=True)
#               (5): Sigmoid()
#             )
#           )
#           (pointwise): Sequential(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth()
#       )
#       (2): MBConv(
#         (expansion): Sequential(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depthwise): DepthwiseSeparableConv(
#           (depthwise): Sequential(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU()
#           )
#           (se): SEBlock(
#             (se): Sequential(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): Flatten(start_dim=1, end_dim=-1)
#               (2): Linear(in_features=672, out_features=28, bias=True)
#               (3): SiLU()
#               (4): Linear(in_features=28, out_features=672, bias=True)
#               (5): Sigmoid()
#             )
#           )
#           (pointwise): Sequential(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth()
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (expansion): Sequential(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depthwise): DepthwiseSeparableConv(
#           (depthwise): Sequential(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU()
#           )
#           (se): SEBlock(
#             (se): Sequential(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): Flatten(start_dim=1, end_dim=-1)
#               (2): Linear(in_features=672, out_features=28, bias=True)
#               (3): SiLU()
#               (4): Linear(in_features=28, out_features=672, bias=True)
#               (5): Sigmoid()
#             )
#           )
#           (pointwise): Sequential(
#             (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth()
#       )
#       (1): MBConv(
#         (expansion): Sequential(
#           (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depthwise): DepthwiseSeparableConv(
#           (depthwise): Sequential(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU()
#           )
#           (se): SEBlock(
#             (se): Sequential(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): Flatten(start_dim=1, end_dim=-1)
#               (2): Linear(in_features=1152, out_features=48, bias=True)
#               (3): SiLU()
#               (4): Linear(in_features=48, out_features=1152, bias=True)
#               (5): Sigmoid()
#             )
#           )
#           (pointwise): Sequential(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth()
#       )
#       (2): MBConv(
#         (expansion): Sequential(
#           (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depthwise): DepthwiseSeparableConv(
#           (depthwise): Sequential(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU()
#           )
#           (se): SEBlock(
#             (se): Sequential(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): Flatten(start_dim=1, end_dim=-1)
#               (2): Linear(in_features=1152, out_features=48, bias=True)
#               (3): SiLU()
#               (4): Linear(in_features=48, out_features=1152, bias=True)
#               (5): Sigmoid()
#             )
#           )
#           (pointwise): Sequential(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth()
#       )
#       (3): MBConv(
#         (expansion): Sequential(
#           (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depthwise): DepthwiseSeparableConv(
#           (depthwise): Sequential(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU()
#           )
#           (se): SEBlock(
#             (se): Sequential(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): Flatten(start_dim=1, end_dim=-1)
#               (2): Linear(in_features=1152, out_features=48, bias=True)
#               (3): SiLU()
#               (4): Linear(in_features=48, out_features=1152, bias=True)
#               (5): Sigmoid()
#             )
#           )
#           (pointwise): Sequential(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth()
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (expansion): Sequential(
#           (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depthwise): DepthwiseSeparableConv(
#           (depthwise): Sequential(
#             (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU()
#           )
#           (se): SEBlock(
#             (se): Sequential(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): Flatten(start_dim=1, end_dim=-1)
#               (2): Linear(in_features=1152, out_features=48, bias=True)
#               (3): SiLU()
#               (4): Linear(in_features=48, out_features=1152, bias=True)
#               (5): Sigmoid()
#             )
#           )
#           (pointwise): Sequential(
#             (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth()
#       )
#     )
#   )
#   (head): Sequential(
#     (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): SiLU()
#   )
#   (global_pool): AdaptiveAvgPool2d(output_size=1)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (classifier): Linear(in_features=1280, out_features=100, bias=True)
# )
#
# Total parameters: 4,135,648

# %% [markdown]
# ## Training Configuration
#
# Re-initialize the model for training, then configure the loss, AMP scaler, SGD optimizer, OneCycleLR schedule, and best/last checkpoint paths.
#
# The visible code currently uses `EPOCHS = 120`; the stored training output below came from the `efficient_net_v5_onecycle150_100` checkpoint run.

# %%
# ── LR Tuning: OneCycleLR ────────────────────────────────────────────────
# Problem: CosineAnnealingLR decays LR monotonically → val loss plateaus
#          when LR becomes very small, the model stops improving.
# Fix: OneCycleLR uses a single aggressive cycle:
#   Phase 1 (pct_start): LR warms up from max_lr/div_factor → max_lr
#   Phase 2: LR anneals from max_lr → max_lr / final_div_factor (cosine)
# Benefits: stronger regularisation via LR annealing, avoids plateau.
#
EPOCHS = 120
STEPS_PER_EPOCH = len(trainloader)  # 625 batches

model = EfficientNet().to(device)

criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
scaler    = GradScaler('cuda')

optimizer = optim.SGD(
    model.parameters(),
    lr=0.05,          # will be overridden by OneCycleLR
    momentum=0.9,
    weight_decay=5e-4,
    nesterov=True,
)

scheduler = optim.lr_scheduler.OneCycleLR(
    optimizer,
    max_lr=0.1,              # peak LR (2× previous starting LR)
    steps_per_epoch=STEPS_PER_EPOCH,
    epochs=EPOCHS,
    pct_start=0.10,           # 10% warmup
    anneal_strategy='cos',
    div_factor=10.0,         # initial_lr = max_lr / 10  = 0.01
    final_div_factor=1e4,    # min_lr    = initial_lr / 1e4 = 1e-6
)

# scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=120, eta_min=1e-5)

MODEL_NAME = 'efficient_net_onecycle_100_lanczos'
checkpoint = ModelCheckpoint(
    model,
    checkpoint_path=f'../../checkpoint/{MODEL_NAME}_last.pth',
    best_model_path=f'../../checkpoint/{MODEL_NAME}_best.pth',
    mode='max',
    verbose=True,
)

# %% [markdown]
# ## Training
#
# Run the shared `fit` loop with MixUp and label smoothing for regularization. `step_scheduler_per_batch=True` is required because `OneCycleLR` expects one scheduler step per batch.

# %%
train_losses, val_losses, val_accs = fit(
    model, trainloader, valloader, criterion,
    optimizer, scheduler, scaler, device,
    EPOCHS, checkpoint,
    mixup_alpha=0.2,              # mild MixUp for extra regularization
    step_scheduler_per_batch=True, # OneCycleLR steps every batch
    log=True,
)
# Out:
# [RunLogger] Logging to 'C:\Users\asmit\PycharmProjects\CIFAR_10\logs\2357617671/'  —  run: 'efficientnet_20260530_152839'
# [ModelCheckpoint] New best (max): 8.4200 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [ 1/120]  Train Loss: 4.4022  Val Loss: 4.1180  Val Acc: 8.42%  LR: 0.011534  Time: 69.72s
# [ModelCheckpoint] New best (max): 18.3800 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [ 2/120]  Train Loss: 4.0660  Val Loss: 3.5988  Val Acc: 18.38%  LR: 0.016032  Time: 28.37s
# [ModelCheckpoint] New best (max): 27.5300 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [ 3/120]  Train Loss: 3.8180  Val Loss: 3.2168  Val Acc: 27.53%  LR: 0.023187  Time: 28.23s
# [ModelCheckpoint] New best (max): 34.7600 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [ 4/120]  Train Loss: 3.5294  Val Loss: 2.9460  Val Acc: 34.76%  LR: 0.032511  Time: 28.19s
# [ModelCheckpoint] New best (max): 39.5500 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [ 5/120]  Train Loss: 3.3348  Val Loss: 2.7220  Val Acc: 39.55%  LR: 0.043368  Time: 28.33s
# [ModelCheckpoint] New best (max): 42.4200 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [ 6/120]  Train Loss: 3.1836  Val Loss: 2.6361  Val Acc: 42.42%  LR: 0.055019  Time: 28.31s
# [ModelCheckpoint] New best (max): 45.4700 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [ 7/120]  Train Loss: 3.0815  Val Loss: 2.5206  Val Acc: 45.47%  LR: 0.066668  Time: 28.45s
# [ModelCheckpoint] New best (max): 47.8300 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [ 8/120]  Train Loss: 2.9868  Val Loss: 2.4436  Val Acc: 47.83%  LR: 0.077522  Time: 28.29s
# Epoch [ 9/120]  Train Loss: 2.9558  Val Loss: 2.5081  Val Acc: 46.61%  LR: 0.086840  Time: 28.38s
# [ModelCheckpoint] New best (max): 50.1300 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [10/120]  Train Loss: 2.8795  Val Loss: 2.3797  Val Acc: 50.13%  LR: 0.093987  Time: 28.41s
# Epoch [11/120]  Train Loss: 2.8528  Val Loss: 2.4036  Val Acc: 49.28%  LR: 0.098476  Time: 28.29s
# [ModelCheckpoint] New best (max): 51.9400 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [12/120]  Train Loss: 2.8319  Val Loss: 2.3232  Val Acc: 51.94%  LR: 0.100000  Time: 28.41s
# [ModelCheckpoint] New best (max): 52.0200 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [13/120]  Train Loss: 2.8102  Val Loss: 2.3107  Val Acc: 52.02%  LR: 0.099979  Time: 28.11s
# [ModelCheckpoint] New best (max): 54.6000 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [14/120]  Train Loss: 2.8068  Val Loss: 2.2532  Val Acc: 54.60%  LR: 0.099915  Time: 28.22s
# Epoch [15/120]  Train Loss: 2.7824  Val Loss: 2.4446  Val Acc: 49.41%  LR: 0.099809  Time: 28.14s
# Epoch [16/120]  Train Loss: 2.8123  Val Loss: 2.3404  Val Acc: 50.56%  LR: 0.099661  Time: 28.18s
# Epoch [17/120]  Train Loss: 2.7589  Val Loss: 2.3021  Val Acc: 53.09%  LR: 0.099471  Time: 28.19s
# Epoch [18/120]  Train Loss: 2.7377  Val Loss: 2.2979  Val Acc: 52.05%  LR: 0.099240  Time: 28.31s
# Epoch [19/120]  Train Loss: 2.7201  Val Loss: 2.3111  Val Acc: 52.93%  LR: 0.098966  Time: 28.25s
# Epoch [20/120]  Train Loss: 2.7209  Val Loss: 2.3527  Val Acc: 51.83%  LR: 0.098651  Time: 28.31s
# Epoch [21/120]  Train Loss: 2.7238  Val Loss: 2.2682  Val Acc: 54.04%  LR: 0.098295  Time: 28.42s
# Epoch [22/120]  Train Loss: 2.7276  Val Loss: 2.2317  Val Acc: 54.60%  LR: 0.097898  Time: 28.21s
# Epoch [23/120]  Train Loss: 2.7338  Val Loss: 2.3159  Val Acc: 52.87%  LR: 0.097461  Time: 28.40s
# Epoch [24/120]  Train Loss: 2.6775  Val Loss: 2.3410  Val Acc: 52.86%  LR: 0.096983  Time: 28.24s
# Epoch [25/120]  Train Loss: 2.6893  Val Loss: 2.3019  Val Acc: 52.66%  LR: 0.096466  Time: 28.27s
# Epoch [26/120]  Train Loss: 2.6763  Val Loss: 2.2838  Val Acc: 54.39%  LR: 0.095909  Time: 28.28s
# [ModelCheckpoint] New best (max): 55.4800 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [27/120]  Train Loss: 2.6862  Val Loss: 2.2462  Val Acc: 55.48%  LR: 0.095313  Time: 28.28s
# [ModelCheckpoint] New best (max): 57.1200 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [28/120]  Train Loss: 2.6293  Val Loss: 2.1897  Val Acc: 57.12%  LR: 0.094680  Time: 28.22s
# Epoch [29/120]  Train Loss: 2.6370  Val Loss: 2.1858  Val Acc: 56.95%  LR: 0.094008  Time: 28.28s
# Epoch [30/120]  Train Loss: 2.6551  Val Loss: 2.3565  Val Acc: 52.31%  LR: 0.093299  Time: 28.29s
# Epoch [31/120]  Train Loss: 2.6613  Val Loss: 2.2242  Val Acc: 55.94%  LR: 0.092553  Time: 28.26s
# Epoch [32/120]  Train Loss: 2.6528  Val Loss: 2.2347  Val Acc: 55.12%  LR: 0.091772  Time: 28.18s
# Epoch [33/120]  Train Loss: 2.6230  Val Loss: 2.1990  Val Acc: 56.77%  LR: 0.090955  Time: 28.22s
# Epoch [34/120]  Train Loss: 2.6530  Val Loss: 2.4385  Val Acc: 49.65%  LR: 0.090103  Time: 28.30s
# [ModelCheckpoint] New best (max): 57.3500 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [35/120]  Train Loss: 2.5917  Val Loss: 2.1737  Val Acc: 57.35%  LR: 0.089218  Time: 28.23s
# Epoch [36/120]  Train Loss: 2.6058  Val Loss: 2.1735  Val Acc: 57.20%  LR: 0.088299  Time: 28.26s
# [ModelCheckpoint] New best (max): 58.6000 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [37/120]  Train Loss: 2.5995  Val Loss: 2.1398  Val Acc: 58.60%  LR: 0.087348  Time: 28.36s
# Epoch [38/120]  Train Loss: 2.6082  Val Loss: 2.1636  Val Acc: 57.50%  LR: 0.086366  Time: 28.16s
# Epoch [39/120]  Train Loss: 2.5853  Val Loss: 2.1476  Val Acc: 57.66%  LR: 0.085352  Time: 28.24s
# Epoch [40/120]  Train Loss: 2.5596  Val Loss: 2.1733  Val Acc: 57.39%  LR: 0.084309  Time: 28.23s
# Epoch [41/120]  Train Loss: 2.6200  Val Loss: 2.1936  Val Acc: 57.16%  LR: 0.083236  Time: 28.18s
# Epoch [42/120]  Train Loss: 2.4943  Val Loss: 2.2308  Val Acc: 55.36%  LR: 0.082136  Time: 28.18s
# [ModelCheckpoint] New best (max): 59.3200 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [43/120]  Train Loss: 2.5824  Val Loss: 2.1084  Val Acc: 59.32%  LR: 0.081008  Time: 28.21s
# Epoch [44/120]  Train Loss: 2.5501  Val Loss: 2.1840  Val Acc: 56.93%  LR: 0.079854  Time: 28.19s
# Epoch [45/120]  Train Loss: 2.5467  Val Loss: 2.1138  Val Acc: 59.00%  LR: 0.078675  Time: 28.48s
# [ModelCheckpoint] New best (max): 59.9600 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [46/120]  Train Loss: 2.5422  Val Loss: 2.0975  Val Acc: 59.96%  LR: 0.077472  Time: 28.35s
# Epoch [47/120]  Train Loss: 2.5250  Val Loss: 2.2565  Val Acc: 55.22%  LR: 0.076245  Time: 28.28s
# Epoch [48/120]  Train Loss: 2.5326  Val Loss: 2.1984  Val Acc: 56.14%  LR: 0.074996  Time: 28.21s
# Epoch [49/120]  Train Loss: 2.5528  Val Loss: 2.1626  Val Acc: 59.10%  LR: 0.073726  Time: 28.25s
# [ModelCheckpoint] New best (max): 61.1700 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [50/120]  Train Loss: 2.4870  Val Loss: 2.0507  Val Acc: 61.17%  LR: 0.072436  Time: 28.21s
# Epoch [51/120]  Train Loss: 2.5167  Val Loss: 2.1431  Val Acc: 58.53%  LR: 0.071127  Time: 28.22s
# [ModelCheckpoint] New best (max): 61.3400 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [52/120]  Train Loss: 2.4727  Val Loss: 2.0365  Val Acc: 61.34%  LR: 0.069800  Time: 28.28s
# Epoch [53/120]  Train Loss: 2.5402  Val Loss: 2.0900  Val Acc: 59.67%  LR: 0.068456  Time: 28.14s
# Epoch [54/120]  Train Loss: 2.5528  Val Loss: 2.1022  Val Acc: 59.20%  LR: 0.067097  Time: 28.16s
# Epoch [55/120]  Train Loss: 2.5682  Val Loss: 2.0969  Val Acc: 59.60%  LR: 0.065723  Time: 28.20s
# Epoch [56/120]  Train Loss: 2.5589  Val Loss: 2.0891  Val Acc: 60.16%  LR: 0.064336  Time: 28.17s
# Epoch [57/120]  Train Loss: 2.4950  Val Loss: 2.2032  Val Acc: 56.41%  LR: 0.062937  Time: 28.19s
# [ModelCheckpoint] New best (max): 64.1900 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [58/120]  Train Loss: 2.4908  Val Loss: 1.9713  Val Acc: 64.19%  LR: 0.061527  Time: 28.45s
# Epoch [59/120]  Train Loss: 2.5110  Val Loss: 2.0712  Val Acc: 61.21%  LR: 0.060107  Time: 28.35s
# Epoch [60/120]  Train Loss: 2.4793  Val Loss: 2.0770  Val Acc: 60.50%  LR: 0.058678  Time: 29.57s
# Epoch [61/120]  Train Loss: 2.5009  Val Loss: 2.0391  Val Acc: 61.23%  LR: 0.057242  Time: 28.81s
# Epoch [62/120]  Train Loss: 2.4785  Val Loss: 2.0903  Val Acc: 59.48%  LR: 0.055800  Time: 28.48s
# Epoch [63/120]  Train Loss: 2.4759  Val Loss: 2.0803  Val Acc: 59.96%  LR: 0.054354  Time: 28.90s
# Epoch [64/120]  Train Loss: 2.4724  Val Loss: 2.0273  Val Acc: 61.27%  LR: 0.052903  Time: 28.87s
# Epoch [65/120]  Train Loss: 2.4594  Val Loss: 2.0015  Val Acc: 61.67%  LR: 0.051450  Time: 29.04s
# Epoch [66/120]  Train Loss: 2.4103  Val Loss: 2.0910  Val Acc: 60.15%  LR: 0.049996  Time: 29.01s
# Epoch [67/120]  Train Loss: 2.4454  Val Loss: 1.9635  Val Acc: 63.78%  LR: 0.048542  Time: 29.11s
# Epoch [68/120]  Train Loss: 2.4276  Val Loss: 2.0455  Val Acc: 61.63%  LR: 0.047089  Time: 29.36s
# Epoch [69/120]  Train Loss: 2.4150  Val Loss: 1.9865  Val Acc: 62.93%  LR: 0.045638  Time: 28.88s
# [ModelCheckpoint] New best (max): 64.7200 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [70/120]  Train Loss: 2.4404  Val Loss: 1.9203  Val Acc: 64.72%  LR: 0.044191  Time: 28.85s
# [ModelCheckpoint] New best (max): 65.5600 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [71/120]  Train Loss: 2.4176  Val Loss: 1.9043  Val Acc: 65.56%  LR: 0.042749  Time: 28.87s
# Epoch [72/120]  Train Loss: 2.4029  Val Loss: 2.0045  Val Acc: 62.48%  LR: 0.041314  Time: 29.27s
# Epoch [73/120]  Train Loss: 2.3973  Val Loss: 1.9607  Val Acc: 63.76%  LR: 0.039885  Time: 29.44s
# Epoch [74/120]  Train Loss: 2.3785  Val Loss: 1.9405  Val Acc: 64.82%  LR: 0.038465  Time: 29.30s
# Epoch [75/120]  Train Loss: 2.3790  Val Loss: 2.0002  Val Acc: 62.57%  LR: 0.037055  Time: 29.20s
# Epoch [76/120]  Train Loss: 2.3571  Val Loss: 1.9580  Val Acc: 63.85%  LR: 0.035656  Time: 29.02s
# [ModelCheckpoint] New best (max): 66.7900 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [77/120]  Train Loss: 2.3703  Val Loss: 1.8930  Val Acc: 66.79%  LR: 0.034269  Time: 29.04s
# Epoch [78/120]  Train Loss: 2.3736  Val Loss: 1.9715  Val Acc: 64.15%  LR: 0.032895  Time: 29.29s
# Epoch [79/120]  Train Loss: 2.2944  Val Loss: 1.8882  Val Acc: 66.39%  LR: 0.031536  Time: 30.81s
# Epoch [80/120]  Train Loss: 2.3697  Val Loss: 1.8708  Val Acc: 66.67%  LR: 0.030192  Time: 30.97s
# [ModelCheckpoint] New best (max): 67.2200 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [81/120]  Train Loss: 2.2580  Val Loss: 1.8539  Val Acc: 67.22%  LR: 0.028866  Time: 29.92s
# Epoch [82/120]  Train Loss: 2.2642  Val Loss: 1.8767  Val Acc: 66.13%  LR: 0.027557  Time: 29.79s
# Epoch [83/120]  Train Loss: 2.4040  Val Loss: 1.8953  Val Acc: 66.06%  LR: 0.026267  Time: 28.88s
# Epoch [84/120]  Train Loss: 2.3022  Val Loss: 1.9537  Val Acc: 64.49%  LR: 0.024997  Time: 28.86s
# [ModelCheckpoint] New best (max): 67.5600 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [85/120]  Train Loss: 2.2522  Val Loss: 1.8456  Val Acc: 67.56%  LR: 0.023748  Time: 28.94s
# Epoch [86/120]  Train Loss: 2.2779  Val Loss: 1.8594  Val Acc: 66.18%  LR: 0.022521  Time: 29.01s
# [ModelCheckpoint] New best (max): 68.5500 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [87/120]  Train Loss: 2.2608  Val Loss: 1.8132  Val Acc: 68.55%  LR: 0.021318  Time: 28.78s
# Epoch [88/120]  Train Loss: 2.2811  Val Loss: 1.8245  Val Acc: 68.08%  LR: 0.020139  Time: 28.88s
# Epoch [89/120]  Train Loss: 2.2353  Val Loss: 1.8272  Val Acc: 68.48%  LR: 0.018985  Time: 28.89s
# [ModelCheckpoint] New best (max): 69.2500 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [90/120]  Train Loss: 2.2477  Val Loss: 1.7802  Val Acc: 69.25%  LR: 0.017858  Time: 28.86s
# [ModelCheckpoint] New best (max): 69.3900 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [91/120]  Train Loss: 2.1880  Val Loss: 1.7849  Val Acc: 69.39%  LR: 0.016758  Time: 28.84s
# Epoch [92/120]  Train Loss: 2.1562  Val Loss: 1.8145  Val Acc: 68.63%  LR: 0.015685  Time: 28.63s
# [ModelCheckpoint] New best (max): 69.6600 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [93/120]  Train Loss: 2.1893  Val Loss: 1.7735  Val Acc: 69.66%  LR: 0.014642  Time: 28.50s
# [ModelCheckpoint] New best (max): 71.3200 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [94/120]  Train Loss: 2.1382  Val Loss: 1.7204  Val Acc: 71.32%  LR: 0.013629  Time: 28.63s
# Epoch [95/120]  Train Loss: 2.1384  Val Loss: 1.7531  Val Acc: 70.20%  LR: 0.012647  Time: 28.64s
# [ModelCheckpoint] New best (max): 71.4900 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [96/120]  Train Loss: 2.1831  Val Loss: 1.7218  Val Acc: 71.49%  LR: 0.011696  Time: 28.58s
# Epoch [97/120]  Train Loss: 2.1144  Val Loss: 1.7388  Val Acc: 71.41%  LR: 0.010777  Time: 28.55s
# [ModelCheckpoint] New best (max): 72.9000 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [98/120]  Train Loss: 2.0724  Val Loss: 1.6946  Val Acc: 72.90%  LR: 0.009892  Time: 28.59s
# Epoch [99/120]  Train Loss: 2.0345  Val Loss: 1.6976  Val Acc: 72.59%  LR: 0.009041  Time: 28.56s
# [ModelCheckpoint] New best (max): 73.0300 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [100/120]  Train Loss: 2.0591  Val Loss: 1.6764  Val Acc: 73.03%  LR: 0.008224  Time: 28.55s
# Epoch [101/120]  Train Loss: 2.0386  Val Loss: 1.7453  Val Acc: 71.92%  LR: 0.007443  Time: 28.57s
# [ModelCheckpoint] New best (max): 73.5700 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [102/120]  Train Loss: 2.0703  Val Loss: 1.6442  Val Acc: 73.57%  LR: 0.006697  Time: 28.61s
# [ModelCheckpoint] New best (max): 73.9100 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [103/120]  Train Loss: 2.0146  Val Loss: 1.6534  Val Acc: 73.91%  LR: 0.005989  Time: 28.56s
# Epoch [104/120]  Train Loss: 2.0083  Val Loss: 1.6623  Val Acc: 73.84%  LR: 0.005317  Time: 28.57s
# Epoch [105/120]  Train Loss: 2.0769  Val Loss: 1.6431  Val Acc: 73.88%  LR: 0.004684  Time: 28.50s
# [ModelCheckpoint] New best (max): 74.5200 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [106/120]  Train Loss: 1.9303  Val Loss: 1.6169  Val Acc: 74.52%  LR: 0.004088  Time: 28.55s
# [ModelCheckpoint] New best (max): 75.1500 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [107/120]  Train Loss: 1.9554  Val Loss: 1.6167  Val Acc: 75.15%  LR: 0.003532  Time: 28.65s
# [ModelCheckpoint] New best (max): 75.5400 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [108/120]  Train Loss: 1.9170  Val Loss: 1.5931  Val Acc: 75.54%  LR: 0.003015  Time: 28.62s
# Epoch [109/120]  Train Loss: 1.9617  Val Loss: 1.6063  Val Acc: 75.14%  LR: 0.002537  Time: 28.52s
# [ModelCheckpoint] New best (max): 75.7300 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [110/120]  Train Loss: 1.9284  Val Loss: 1.5745  Val Acc: 75.73%  LR: 0.002100  Time: 28.66s
# [ModelCheckpoint] New best (max): 76.5200 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [111/120]  Train Loss: 1.8619  Val Loss: 1.5639  Val Acc: 76.52%  LR: 0.001703  Time: 28.63s
# [ModelCheckpoint] New best (max): 76.8900 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [112/120]  Train Loss: 1.8444  Val Loss: 1.5433  Val Acc: 76.89%  LR: 0.001348  Time: 28.55s
# [ModelCheckpoint] New best (max): 76.9100 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [113/120]  Train Loss: 1.9037  Val Loss: 1.5514  Val Acc: 76.91%  LR: 0.001033  Time: 28.74s
# [ModelCheckpoint] New best (max): 77.1700 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [114/120]  Train Loss: 1.8868  Val Loss: 1.5381  Val Acc: 77.17%  LR: 0.000760  Time: 28.63s
# Epoch [115/120]  Train Loss: 1.8009  Val Loss: 1.5702  Val Acc: 76.50%  LR: 0.000528  Time: 28.57s
# Epoch [116/120]  Train Loss: 1.8314  Val Loss: 1.5415  Val Acc: 77.14%  LR: 0.000339  Time: 28.53s
# [ModelCheckpoint] New best (max): 77.4800 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [117/120]  Train Loss: 1.7959  Val Loss: 1.5331  Val Acc: 77.48%  LR: 0.000191  Time: 28.47s
# [ModelCheckpoint] New best (max): 77.5400 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [118/120]  Train Loss: 1.7823  Val Loss: 1.5324  Val Acc: 77.54%  LR: 0.000085  Time: 28.69s
# Epoch [119/120]  Train Loss: 1.8276  Val Loss: 1.5299  Val Acc: 77.52%  LR: 0.000022  Time: 28.78s
# [ModelCheckpoint] New best (max): 77.6100 — saved to ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth
# Epoch [120/120]  Train Loss: 1.7333  Val Loss: 1.5237  Val Acc: 77.61%  LR: 0.000001  Time: 28.65s
#
# Finished Training in 57.87 minutes
# Best Validation Accuracy: 77.61%

# %% [markdown]
# ## Learning Curves
#
# Plot training loss, validation loss, and validation accuracy to inspect convergence and check for overfitting.

# %%
plot_training_curves(train_losses, val_losses, val_accs)

# %% [markdown]
# ## Test Evaluation
#
# Restore the best validation checkpoint, evaluate on the official CIFAR-100 test split, and print per-class accuracy sorted from strongest to weakest.

# %%
checkpoint.restore_best_weights()

overall_acc, per_class = test_accuracy(model, testloader, CIFAR100_CLASSES, device)
print(f'Test Accuracy: {overall_acc:.2f}%\n')

print('Per-class accuracies (best first):')
sorted_classes = sorted(per_class.items(), key=lambda x: x[1], reverse=True)
for cls, acc in sorted_classes:
    bar = '█' * int(acc / 5)
    print(f'  {cls:<20s} {acc:5.1f}%  {bar}')
# Out:
# [ModelCheckpoint] Restored best weights from ..\checkpoint\efficient_net_onecycle_100_lanczos_best.pth (score=77.6100)
# Test Accuracy: 77.49%
#
# Per-class accuracies (best first):
#   skunk                 97.0%  ███████████████████
#   orange                95.0%  ███████████████████
#   road                  95.0%  ███████████████████
#   sunflower             95.0%  ███████████████████
#   wardrobe              95.0%  ███████████████████
#   chair                 94.0%  ██████████████████
#   tractor               94.0%  ██████████████████
#   apple                 93.0%  ██████████████████
#   bicycle               93.0%  ██████████████████
#   keyboard              92.0%  ██████████████████
#   motorcycle            92.0%  ██████████████████
#   skyscraper            92.0%  ██████████████████
#   chimpanzee            91.0%  ██████████████████
#   pickup_truck          91.0%  ██████████████████
#   tank                  91.0%  ██████████████████
#   aquarium_fish         90.0%  ██████████████████
#   raccoon               90.0%  ██████████████████
#   bottle                89.0%  █████████████████
#   castle                89.0%  █████████████████
#   mountain              89.0%  █████████████████
#   palm_tree             89.0%  █████████████████
#   streetcar             89.0%  █████████████████
#   television            88.0%  █████████████████
#   lawn_mower            87.0%  █████████████████
#   orchid                87.0%  █████████████████
#   tiger                 87.0%  █████████████████
#   bee                   86.0%  █████████████████
#   cockroach             86.0%  █████████████████
#   plain                 86.0%  █████████████████
#   trout                 86.0%  █████████████████
#   lion                  85.0%  █████████████████
#   poppy                 85.0%  █████████████████
#   hamster               84.0%  ████████████████
#   train                 84.0%  ████████████████
#   bed                   83.0%  ████████████████
#   butterfly             83.0%  ████████████████
#   cup                   83.0%  ████████████████
#   fox                   83.0%  ████████████████
#   pear                  83.0%  ████████████████
#   sea                   83.0%  ████████████████
#   spider                82.0%  ████████████████
#   wolf                  82.0%  ████████████████
#   bridge                81.0%  ████████████████
#   camel                 81.0%  ████████████████
#   cloud                 81.0%  ████████████████
#   leopard               81.0%  ████████████████
#   rocket                81.0%  ████████████████
#   worm                  81.0%  ████████████████
#   can                   80.0%  ████████████████
#   clock                 79.0%  ███████████████
#   porcupine             79.0%  ███████████████
#   telephone             79.0%  ███████████████
#   crab                  78.0%  ███████████████
#   dinosaur              78.0%  ███████████████
#   elephant              78.0%  ███████████████
#   house                 78.0%  ███████████████
#   whale                 78.0%  ███████████████
#   plate                 77.0%  ███████████████
#   lamp                  76.0%  ███████████████
#   rose                  76.0%  ███████████████
#   sweet_pepper          76.0%  ███████████████
#   oak_tree              75.0%  ███████████████
#   table                 75.0%  ███████████████
#   beetle                74.0%  ██████████████
#   kangaroo              74.0%  ██████████████
#   mushroom              74.0%  ██████████████
#   snail                 74.0%  ██████████████
#   bus                   72.0%  ██████████████
#   caterpillar           72.0%  ██████████████
#   dolphin               72.0%  ██████████████
#   snake                 72.0%  ██████████████
#   flatfish              71.0%  ██████████████
#   rabbit                69.0%  █████████████
#   willow_tree           69.0%  █████████████
#   crocodile             68.0%  █████████████
#   squirrel              68.0%  █████████████
#   cattle                67.0%  █████████████
#   couch                 67.0%  █████████████
#   lobster               66.0%  █████████████
#   forest                65.0%  █████████████
#   pine_tree             65.0%  █████████████
#   turtle                65.0%  █████████████
#   woman                 65.0%  █████████████
#   maple_tree            63.0%  ████████████
#   possum                63.0%  ████████████
#   tulip                 63.0%  ████████████
#   baby                  62.0%  ████████████
#   bear                  62.0%  ████████████
#   beaver                62.0%  ████████████
#   lizard                60.0%  ████████████
#   man                   60.0%  ████████████
#   shrew                 60.0%  ████████████
#   mouse                 59.0%  ███████████
#   bowl                  58.0%  ███████████
#   ray                   58.0%  ███████████
#   boy                   56.0%  ███████████
#   shark                 56.0%  ███████████
#   girl                  53.0%  ██████████
#   otter                 50.0%  ██████████
#   seal                  49.0%  █████████
